# %% [markdown]
# ## Goal :
#
# Create a "DASHBOARD" for predicting electricity costs in any given country based on the energy source i.e coal, oil, solar, wind, or nuclear.

# %% [markdown]
# ## Data Collection
# > World Energy Consumption, [Visit Kaggle](https://www.kaggle.com/datasets/pralabhpoudel/world-energy-consumption)
# > Humand Development Index Table, [Visit Site](https://www.theglobaleconomy.com/rankings/human_development/)
#
# ## Data Classification
# > Countries in the dataset will be classified as:
# >* "Developed" : HDI $\geq$ 0.8 & gdp_per_capita $\geq$ $18,750
# >* "Developing" : Otherwise

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
import country_converter as coc

# %%
world_data = pd.read_csv('https://raw.githubusercontent.com/owid/energy-data/master/owid-energy-data.csv')

# %%
world_data.head(15)
# Out:
#         country  year iso_code  population  gdp  biofuel_cons_change_pct  \
# 0   Afghanistan  1900      AFG   4832414.0  NaN                      NaN
# 1   Afghanistan  1901      AFG   4879685.0  NaN                      NaN
# 2   Afghanistan  1902      AFG   4935122.0  NaN                      NaN
# 3   Afghanistan  1903      AFG   4998861.0  NaN                      NaN
# 4   Afghanistan  1904      AFG   5063419.0  NaN                      NaN
# 5   Afghanistan  1905      AFG   5128808.0  NaN                      NaN
# 6   Afghanistan  1906      AFG   5195038.0  NaN                      NaN
# 7   Afghanistan  1907      AFG   5262120.0  NaN                      NaN
# 8   Afghanistan  1908      AFG   5330065.0  NaN                      NaN
# 9   Afghanistan  1909      AFG   5467828.0  NaN                      NaN
# 10  Afghanistan  1910      AFG   5681487.0  NaN                      NaN
# 11  Afghanistan  1911      AFG   5977589.0  NaN                      NaN
# 12  Afghanistan  1912      AFG   6363186.0  NaN                      NaN
# 13  Afghanistan  1913      AFG   6845878.0  NaN                      NaN
# 14  Afghanistan  1914      AFG   7365181.0  NaN                      NaN
#
#     biofuel_cons_change_twh  biofuel_cons_per_capita  biofuel_consumption  \
# 0                       NaN                      NaN                  NaN
# 1                       NaN                      NaN                  NaN
# 2                       NaN                      NaN                  NaN
# 3                       NaN                      NaN                  NaN
# 4                       NaN                      NaN                  NaN
# 5                       NaN                      NaN                  NaN
# 6                       NaN                      NaN                  NaN
# 7                       NaN                      NaN                  NaN
# 8                       NaN                      NaN                  NaN
# 9                       NaN                      NaN                  NaN
# 10                      NaN                      NaN                  NaN
# 11                      NaN                      NaN                  NaN
# 12                      NaN                      NaN                  NaN
# 13                      NaN                      NaN                  NaN
# 14                      NaN                      NaN                  NaN
#
#     biofuel_elec_per_capita  ...  solar_share_elec  solar_share_energy  \
# 0                       NaN  ...               NaN                 NaN
# 1                       NaN  ...               NaN                 NaN
# 2                       NaN  ...               NaN                 NaN
# 3                       NaN  ...               NaN                 NaN
# 4                       NaN  ...               NaN                 NaN
# 5                       NaN  ...               NaN                 NaN
# 6                       NaN  ...               NaN                 NaN
# 7                       NaN  ...               NaN                 NaN
# 8                       NaN  ...               NaN                 NaN
# 9                       NaN  ...               NaN                 NaN
# 10                      NaN  ...               NaN                 NaN
# 11                      NaN  ...               NaN                 NaN
# 12                      NaN  ...               NaN                 NaN
# 13                      NaN  ...               NaN                 NaN
# 14                      NaN  ...               NaN                 NaN
#
#     wind_cons_change_pct  wind_cons_change_twh  wind_consumption  \
# 0                    NaN                   NaN               NaN
# 1                    NaN                   NaN               NaN
# 2                    NaN                   NaN               NaN
# 3                    NaN                   NaN               NaN
# 4                    NaN                   NaN               NaN
# 5                    NaN                   NaN               NaN
# 6                    NaN                   NaN               NaN
# 7                    NaN                   NaN               NaN
# 8                    NaN                   NaN               NaN
# 9                    NaN                   NaN               NaN
# 10                   NaN                   NaN               NaN
# 11                   NaN                   NaN               NaN
# 12                   NaN                   NaN               NaN
# 13                   NaN                   NaN               NaN
# 14                   NaN                   NaN               NaN
#
#     wind_elec_per_capita  wind_electricity  wind_energy_per_capita  \
# 0                    NaN               NaN                     NaN
# 1                    NaN               NaN                     NaN
# 2                    NaN               NaN                     NaN
# 3                    NaN               NaN                     NaN
# 4                    NaN               NaN                     NaN
# 5                    NaN               NaN                     NaN
# 6                    NaN               NaN                     NaN
# 7                    NaN               NaN                     NaN
# 8                    NaN               NaN                     NaN
# 9                    NaN               NaN                     NaN
# 10                   NaN               NaN                     NaN
# 11                   NaN               NaN                     NaN
# 12                   NaN               NaN                     NaN
# 13                   NaN               NaN                     NaN
# 14                   NaN               NaN                     NaN
#
#     wind_share_elec  wind_share_energy
# 0               NaN                NaN
# 1               NaN                NaN
# 2               NaN                NaN
# 3               NaN                NaN
# 4               NaN                NaN
# 5               NaN                NaN
# 6               NaN                NaN
# 7               NaN                NaN
# 8               NaN                NaN
# 9               NaN                NaN
# 10              NaN                NaN
# 11              NaN                NaN
# 12              NaN                NaN
# 13              NaN                NaN
# 14              NaN                NaN
#
# [15 rows x 129 columns]

# %% [markdown]
# Load Webscraped Data for the HDI values for countries

# %%
import requests
from bs4 import BeautifulSoup

# %%
url = "https://www.theglobaleconomy.com/rankings/human_development/"
page = requests.get(url)

# Webscrape
soup = BeautifulSoup(page.content, 'html.parser')
table = soup.find("table", attrs={"id": "benchmarkTable"})
hdi_table = pd.read_html(str(table))[0].drop('Available data', axis=1)

hdi_table.columns = ["country", "hdi_2021", "hdi_rank_2021"]

# %%
hdi_table.head(20)
# Out:
#           country  hdi_2021  hdi_rank_2021
# 0     Switzerland     0.962              1
# 1          Norway     0.961              2
# 2         Iceland     0.959              3
# 3       Hong Kong     0.952              4
# 4       Australia     0.951              5
# 5         Denmark     0.948              6
# 6          Sweden     0.947              7
# 7         Ireland     0.945              8
# 8         Germany     0.942              9
# 9     Netherlands     0.941             10
# 10        Finland     0.940             11
# 11      Singapore     0.939             12
# 12        Belgium     0.937             13
# 13    New Zealand     0.937             14
# 14         Canada     0.936             15
# 15  Liechtenstein     0.935             16
# 16     Luxembourg     0.930             17
# 17    UA Emirates     0.929             18
# 18          Japan     0.925             19
# 19    South Korea     0.925             20

# %% [markdown]
# ## Data Wrangling

# %%
# replace some country names to match with country names in the world_data
hdi_table['country'] = hdi_table['country'].replace(['USA', 'R. of Congo', 'UK', 'UAE'], 
                                                    ['United States', 'Congo', 'United Kingdom', 'United Arab Emirates'])

# %%
# inner merge two datatable on the country column
world_data = pd.merge(world_data, hdi_table, on = "country")

# %%
# create new column gdp_per_capita
world_data["gdp_per_capita"] = round(world_data["gdp"] / world_data["population"], 2)

# create new column status based on predetermined conditions
world_data["status"] = ["developed" if x >= 18750 and y >= 0.8 else "developing" for x,y in zip(world_data["gdp_per_capita"], world_data["hdi_2021"])]

# create new column continent based on coutry's ISO code
world_data["continent"] = coc.convert(names = world_data["iso_code"].tolist(), to = "continent", src = "ISO3")

# %%
# reorder the columns 
columns_order = ['country', 'year', 'iso_code', 'continent', 'status', 'population', 'hdi_rank_2021', 'hdi_2021', 'gdp','gdp_per_capita'] + [col for col in world_data.columns if col not in ['country', 'year', 'iso_code', 'continent','status', 'population', 'hdi_rank_2021', 'hdi_2021', 'gdp', 'gdp_per_capita']]

world_data = world_data[columns_order]

# %%
world_data
# Out:
#            country  year iso_code continent      status  population  \
# 0      Afghanistan  1900      AFG      Asia  developing   4832414.0
# 1      Afghanistan  1901      AFG      Asia  developing   4879685.0
# 2      Afghanistan  1902      AFG      Asia  developing   4935122.0
# 3      Afghanistan  1903      AFG      Asia  developing   4998861.0
# 4      Afghanistan  1904      AFG      Asia  developing   5063419.0
# ...            ...   ...      ...       ...         ...         ...
# 13510     Zimbabwe  2017      ZWE    Africa  developing  14751101.0
# 13511     Zimbabwe  2018      ZWE    Africa  developing  15052191.0
# 13512     Zimbabwe  2019      ZWE    Africa  developing  15354606.0
# 13513     Zimbabwe  2020      ZWE    Africa  developing  15669663.0
# 13514     Zimbabwe  2021      ZWE    Africa  developing  15993525.0
#
#        hdi_rank_2021  hdi_2021           gdp  gdp_per_capita  ...  \
# 0                173     0.478           NaN             NaN  ...
# 1                173     0.478           NaN             NaN  ...
# 2                173     0.478           NaN             NaN  ...
# 3                173     0.478           NaN             NaN  ...
# 4                173     0.478           NaN             NaN  ...
# ...              ...       ...           ...             ...  ...
# 13510            141     0.593  2.194784e+10         1487.88  ...
# 13511            141     0.593  2.271535e+10         1509.11  ...
# 13512            141     0.593           NaN             NaN  ...
# 13513            141     0.593           NaN             NaN  ...
# 13514            141     0.593           NaN             NaN  ...
#
#        solar_share_elec  solar_share_energy  wind_cons_change_pct  \
# 0                   NaN                 NaN                   NaN
# 1                   NaN                 NaN                   NaN
# 2                   NaN                 NaN                   NaN
# 3                   NaN                 NaN                   NaN
# 4                   NaN                 NaN                   NaN
# ...                 ...                 ...                   ...
# 13510             0.136                 NaN                   NaN
# 13511             0.218                 NaN                   NaN
# 13512             0.364                 NaN                   NaN
# 13513             0.395                 NaN                   NaN
# 13514             0.498                 NaN                   NaN
#
#        wind_cons_change_twh  wind_consumption  wind_elec_per_capita  \
# 0                       NaN               NaN                   NaN
# 1                       NaN               NaN                   NaN
# 2                       NaN               NaN                   NaN
# 3                       NaN               NaN                   NaN
# 4                       NaN               NaN                   NaN
# ...                     ...               ...                   ...
# 13510                   NaN               NaN                   0.0
# 13511                   NaN               NaN                   0.0
# 13512                   NaN               NaN                   0.0
# 13513                   NaN               NaN                   0.0
# 13514                   NaN               NaN                   0.0
#
#        wind_electricity  wind_energy_per_capita  wind_share_elec  \
# 0                   NaN                     NaN              NaN
# 1                   NaN                     NaN              NaN
# 2                   NaN                     NaN              NaN
# 3                   NaN                     NaN              NaN
# 4                   NaN                     NaN              NaN
# ...                 ...                     ...              ...
# 13510               0.0                     NaN              0.0
# 13511               0.0                     NaN              0.0
# 13512               0.0                     NaN              0.0
# 13513               0.0                     NaN              0.0
# 13514               0.0                     NaN              0.0
#
#        wind_share_energy
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
# ...                  ...
# 13510                NaN
# 13511                NaN
# 13512                NaN
# 13513                NaN
# 13514                NaN
#
# [13515 rows x 134 columns]

# %% [markdown]
# move this dataframe to aws or something so it doesnt have to reload the data everytime

# %%
solar_data = world_data[""]
